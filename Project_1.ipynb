# %%
# Simple Interest Calculation
P = float(input("Enter the Principal amount (P): "))
R = float(input("Enter the Annual Interest Rate (R in %): "))
T = float(input("Enter the Time in years (T): "))

# Formula: A = P * (1 + (R/100) * T)
A = P * (1 + (R / 100) * T)

print(f"\nThe total amount (A) after {T} years is: {A:.2f}")

# Compound Interest Calculation
P = float(input("Enter the Principal amount (P): "))
R = float(input("Enter the Annual Interest Rate (as a decimal, e.g., 0.05 for 5%): "))
n = int(input("Enter the number of times interest is compounded per year (n): "))
t = float(input("Enter the number of years (t): "))

# Formula: A = P * (1 + R/n)**(n*t)
A = P * (1 + R / n)**(n * t)

print(f"\nThe total amount (A) after {t} years is: {A:.2f}")

# Annuity Plan Calculation
PMT = float(input("Enter the regular payment amount (PMT): "))
R = float(input("Enter the Annual Interest Rate (as a decimal): "))
n = int(input("Enter the number of payments per year (n): "))
t = float(input("Enter the number of years (t): "))

# Breaking down the formula for clarity
periodic_rate = R / n
periods = n * t

# Formula: A = PMT * (((1 + periodic_rate)**periods - 1) / periodic_rate)
A = PMT * (((1 + periodic_rate)**periods - 1) / periodic_rate)

print(f"\nThe future value of the Annuity (A) is: {A:.2f}")

# Main execution loop
while True:
    print("\nSelect an option:")
    print("1. Simple Interest")
    print("2. Compound Interest")
    print("3. Annuity Plan")
    print("4. Exit")
    
    choice = input("Enter choice (1-4): ")
    
    if choice == '1':
        calculate_simple_interest()
    elif choice == '2':
        calculate_compound_interest()
    elif choice == '3':
        calculate_annuity_plan()
    elif choice == '4':
        print("Exiting program. Goodbye!")
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# Enter the Principal amount (P):  1
# Enter the Annual Interest Rate (R in %):  1
# Enter the Time in years (T):  1
# The total amount (A) after 1.0 years is: 1.01
# Enter the Principal amount (P):  1
# Enter the Annual Interest Rate (as a decimal, e.g., 0.05 for 5%):  1
# Enter the number of times interest is compounded per year (n):  1
# Enter the number of years (t):  1
# The total amount (A) after 1.0 years is: 2.00
# Enter the regular payment amount (PMT):  1
# Enter the Annual Interest Rate (as a decimal):  1
# Enter the number of payments per year (n):  11
# Enter the number of years (t):  1
# The future value of the Annuity (A) is: 17.65
#
# Select an option:
# 1. Simple Interest
# 2. Compound Interest
# 3. Annuity Plan
# 4. Exit
# Enter choice (1-4):
# Invalid choice. Please try again.
#
# Select an option:
# 1. Simple Interest
# 2. Compound Interest
# 3. Annuity Plan
# 4. Exit
